# %%
#inport pandas and load the dataset
import pandas as pd
df = pd.read_csv('Sales_Dashboard.csv')

# %%
# info about the datset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       500 non-null    str
#  1   Order Date     500 non-null    str
#  2   Customer Name  500 non-null    str
#  3   Product        500 non-null    str
#  4   Category       500 non-null    str
#  5   Region         500 non-null    str
#  6   Salesperson    500 non-null    str
#  7   Quantity       500 non-null    int64
#  8   Unit Price     500 non-null    int64
#  9   Total Sales    500 non-null    int64
#  10  Cost Price     500 non-null    int64
#  11  Profit         500 non-null    int64
#  12  Payment Mode   500 non-null    str
#  13  Order Status   500 non-null    str
# dtypes: int64(5), str(9)
# memory usage: 54.8 KB

# %%
print(df)
# Out:
#     order_id  order_date customer_name   product     category region  \
# 0    ORD0092  19/10/2025        Khushi    Laptop  Electronics   West
# 1    ORD0172  13/01/2025         Rohan    Laptop  Electronics   West
# 2    ORD0410  13/12/2025        Muskan    Laptop  Electronics   East
# 3    ORD0079  11/10/2025         Tanya    Laptop  Electronics   East
# 4    ORD0115  18/02/2025         Rahul    Laptop  Electronics  North
# ..       ...         ...           ...       ...          ...    ...
# 495  ORD0090  13/12/2025      Abhishek     Mouse  Electronics  North
# 496  ORD0153  27/06/2025        Pranav     Mouse  Electronics   East
# 497  ORD0361  14/05/2025         Aryan     Mouse  Electronics  South
# 498  ORD0125  05/11/2025        Anjali     Sugar      Grocery   West
# 499  ORD0389  22/03/2025         Palak  Tea Pack      Grocery   East
#
#     sales_person  quantity  unit_price  total_sales  cost_price  profit  \
# ...

# %%
df = pd.read_csv('Sales_Dashboard.csv')

# %%
df.head()
# Out:
#   Order ID  Order Date Customer Name Product     Category Region Salesperson  \
# 0  ORD0092  19/10/2025        Khushi  Laptop  Electronics   West       Arjun
# 1  ORD0172  13/01/2025         Rohan  Laptop  Electronics   West        Neha
# 2  ORD0410  13/12/2025        Muskan  Laptop  Electronics   East       Karan
# 3  ORD0079  11/10/2025         Tanya  Laptop  Electronics   East        Amit
# 4  ORD0115  18/02/2025         Rahul  Laptop  Electronics  North        Amit
#
#    Quantity  Unit Price  Total Sales  Cost Price  Profit Payment Mode  \
# 0        10       55000       550000       45000  100000  Credit Card
# 1        10       55000       550000       45000  100000          UPI
# 2        10       55000       550000       45000  100000  Credit Card
# 3         9       55000       495000       45000   90000          UPI
# 4         9       55000       495000       45000   90000         Cash
#
#   Order Status
# 0    Delivered
# 1    Cancelled
# 2    Delivered
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'Product', 'Category',
#        'Region', 'Salesperson', 'Quantity', 'Unit Price', 'Total Sales',
#        'Cost Price', 'Profit', 'Payment Mode', 'Order Status'],
#       dtype='str')

# %%
# Convert all columns to lowercase
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['order id', 'order date', 'customer name', 'product', 'category',
#        'region', 'salesperson', 'quantity', 'unit price', 'total sales',
#        'cost price', 'profit', 'payment mode', 'order status'],
#       dtype='str')

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'customer_name', 'product', 'category',
#        'region', 'sales_person', 'quantity', 'unit_price', 'total_sales',
#        'cost_price', 'profit', 'payment_mode', 'order_status'],
#       dtype='str')

# %%
from sqlalchemy import create_engine

# Step 1: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "12345" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "retail_analytics"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "salesperformance"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'salesperformance' in database 'retail_analytics'.
